# %%
# !pip install opencv-python
# !pip install matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\shiva goud\anaconda3\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image in grayscale
img = cv2.imread(r"C:\Users\Shiva Goud\Pictures\Screenshots\chikki.png", 0)

# Check if the image is loaded correctly
if img is None:
    print("Error: Image not found or unable to load.")
else:
    # Apply histogram equalization
    equalized = cv2.equalizeHist(img)
    
    # Displaying  the original image  and equalized image using matplotlib module 
    plt.figure(figsize=(10, 5))

    # Original image
    plt.subplot(1, 2, 1)
    plt.title('Main Image')
    plt.imshow(img, cmap='gray')
    plt.axis('off')

    # Equalized image
    plt.subplot(1, 2, 2)
    plt.title('Equalized Image')
    plt.imshow(equalized, cmap='gray')
    plt.axis('off')

    plt.show()
